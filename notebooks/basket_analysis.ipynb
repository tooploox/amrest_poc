# %% [markdown]
# # Market Basket Analysis

# %% [markdown]
# Based on https://github.com/chris1610/pbpython/blob/master/notebooks/Market_Basket_Intro.ipynb

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style('darkgrid')
random_state = 42
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %matplotlib inline

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Prepare the data (skip if already prepared)

# %%
# %%time

hours = ['0'+str(x)+':00' if x < 10 else str(x)+':00' for x in range(24)]
hour_type = pd.CategoricalDtype(categories=hours, ordered=True)

dtype={'GUESTCHECKID': object,
       'Date': str,
       'HourName': hour_type,
       'QuarterName': "category",
       'GUESTCHECK_SalesNet': np.float64,
       'GUESTCHECK_SalesTax': np.float64,
       'Product': "category",
       'FamilyGroup': "category",
       'MajorGroup': "category",
       'Product_SalesNet': np.float64,
       'Product_SalesTax': np.float64,
       'MPK': object,
       'Restaurant': object,
       'LocationType': "category",
       'Concept': "category",
       'ItemType': "category",
       'ComboMealNum': np.float64,
       'ile_razy': np.float64,
       'SalesChannel': "category"
       }
parse_dates = ['Date']

data = pd.read_csv(os.path.join(os.environ['DATA_PATH'], 'kiosk_produkty/KIOSK_Produkty.csv'), delimiter=";", thousands=',', error_bad_lines=False, dtype=dtype, parse_dates=parse_dates)
# Out:
# CPU times: user 44.5 s, sys: 4.76 s, total: 49.3 s
# Wall time: 49.7 s

# %% [markdown]
# ### Create basket table

# %%
# https://github.com/pandas-dev/pandas/issues/19136#issuecomment-380908428
def reset_index(df):
    '''Returns DataFrame with index as columns'''
    index_df = df.index.to_frame(index=False)
    df = df.reset_index(drop=True)
    #  In merge is important the order in which you pass the dataframes
    # if the index contains a Categorical. 
    # pd.merge(df, index_df, left_index=True, right_index=True) does not work
    return pd.merge(index_df, df, left_index=True, right_index=True)

# %%
# %%time
basket = (data.groupby(['GUESTCHECKID', 'Product'])['ile_razy']
          .sum().unstack())
# Out:
# CPU times: user 16.1 s, sys: 6.56 s, total: 22.7 s
# Wall time: 22.7 s

# %%
# Delete unnecesary data and save memory
del data

# %%
# Convert the units to 1 hot encoded values
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
# %%time
basket = reset_index(basket).fillna(0).set_index('GUESTCHECKID').applymap(encode_units)
# Out:
# CPU times: user 36.5 s, sys: 16.2 s, total: 52.7 s
# Wall time: 53 s

# %%
# %%time
basket_sets = basket.applymap(encode_units)
# Out:
# CPU times: user 8min 51s, sys: 31.8 s, total: 9min 23s
# Wall time: 9min 25s

# %%
basket_sets.head()

# %%
# %%time
basket_sets.to_csv(os.path.join(os.environ['DATA_PATH'], 'basket_sets/basket_sets.csv'))

# %% [markdown]
# ## Load data (if prepared before)

# %%
# %%time
basket_sets = pd.read_csv(os.path.join(os.environ['DATA_PATH'], 'basket_sets/basket_sets.csv'), index_col=0)
# Out:
# CPU times: user 2min 36s, sys: 9.36 s, total: 2min 45s
# Wall time: 2min 46s

# %%
basket_sets.head()
# Out:
#               10HotWings  10Strips  10xCOBHS  10xCOBKent  10xHotWings  \
# GUESTCHECKID
# 1000000246             0         0         0           0            0
# 1000000247             0         0         0           0            0
# 1000000406             0         0         0           0            0
# 1000000415             0         1         0           0            0
# 1000000416             0         0         0           0            0
#
#               10xStripsHS  11HotWings  11Strips  12xHotWings  12xStripsHS  \
# GUESTCHECKID
# 1000000246              0           0         0            0            0
# 1000000247              0           0         0            0            0
# 1000000406              0           0         0            0            0
# 1000000415              0           0         0            0            0
# 1000000416              0           0         0            0            0
#
#               ...  Zinger_wege  app_2xCheesburg  app_2xSmallCoff  \
# GUESTCHECKID  ...
# 1000000246    ...            0                0                0
# 1000000247    ...            0                0                0
# 1000000406    ...            0                0                0
# 1000000415    ...            0                0                0
# 1000000416    ...            0                0                0
#
#               app_Bites&Fries  Halloumi  TwisteHaluBox  TwisteHalum  \
# GUESTCHECKID
# 1000000246                  0         0              0            0
# 1000000247                  0         0              0            0
# 1000000406                  0         0              0            0
# 1000000415                  0         0              0            0
# 1000000416                  0         0              0            0
#
#               mHalloumi  mHalloumiBox  mTwisteHalum
# GUESTCHECKID
# 1000000246            0             0             0
# 1000000247            0             0             0
# 1000000406            0             0             0
# 1000000415            0             0             0
# 1000000416            0             0             0
#
# [5 rows x 585 columns]

# %% [markdown]
# ### Basket analysis

# %%
# %%time
# Build up the frequent items
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
# Out:
# CPU times: user 57 s, sys: 21.9 s, total: 1min 18s
# Wall time: 1min 19s

# %%
frequent_itemsets.head()
# Out:
#    support         itemsets
# 0    0.097      (2HotWings)
# 1    0.119        (2Strips)
# 2    0.091      (5HotWings)
# 3    0.998       (Customer)
# 4    0.077  (DipMajoGarlic)

# %%
# %%time
# Create the rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=5)
# Out:
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 8.03 ms

# %% [markdown]
# #### Remove standard sets - related associations
# If someone buys Bsmart then we expect fries or sandwitch to be in the basket too. This associations are not interesting so we remove them.

# %%
len(rules)
# Out:
# 504

# %%
rows_w_bsmart = (rules['antecedents'].astype(str).str.contains('Bsmart', regex=False) | rules['consequents'].astype(str).str.contains('Bsmart', regex=False))
rows_w_app_bucketfor1 = (rules['antecedents'].astype(str).str.contains('app_bucketfor1', regex=False) | rules['consequents'].astype(str).str.contains('app_bucketfor1', regex=False))
fillter_sets_out = (~rows_w_bsmart & ~rows_w_app_bucketfor1)

# %%
len(rules[fillter_sets_out])
# Out:
# 36

# %%
pd.set_option('display.max_rows', 200)
rules[~rows_w_bsmart & ~rows_w_app_bucketfor1].sort_values('lift', ascending=False).head(20)
# Out:
#                                   antecedents  \
# 98                (DrumstickKent., 2HotWings)
# 93                   (Fries, ex_45BitesAddon)
# 99                          (ex_45BitesAddon)
# 92         (Fries, DrumstickKent., 2HotWings)
# 30                (DrumstickKent., 2HotWings)
# 31                          (ex_45BitesAddon)
# 97                         (Fries, 2HotWings)
# 94          (DrumstickKent., ex_45BitesAddon)
# 40                          (ex_45BitesAddon)
# 39                         (Fries, 2HotWings)
# 96                    (Fries, DrumstickKent.)
# 95               (ex_45BitesAddon, 2HotWings)
# 54                          (ex_45BitesAddon)
# 53                    (Fries, DrumstickKent.)
# 90   (Fries, ex_45BitesAddon, DrumstickKent.)
# 41                                (2HotWings)
# 101                               (2HotWings)
# 38                   (Fries, ex_45BitesAddon)
# 5                                 (2HotWings)
# 33                                (2HotWings)
#
#                                   consequents  antecedent support  \
# 98                   (Fries, ex_45BitesAddon)               0.072
# 93                (DrumstickKent., 2HotWings)               0.083
# 99         (Fries, DrumstickKent., 2HotWings)               0.084
# 92                          (ex_45BitesAddon)               0.071
# 30                          (ex_45BitesAddon)               0.072
# 31                (DrumstickKent., 2HotWings)               0.084
# 97          (DrumstickKent., ex_45BitesAddon)               0.085
# 94                         (Fries, 2HotWings)               0.071
# 40                         (Fries, 2HotWings)               0.084
# 39                          (ex_45BitesAddon)               0.085
# 96               (ex_45BitesAddon, 2HotWings)               0.076
# 95                    (Fries, DrumstickKent.)               0.084
# 54                    (Fries, DrumstickKent.)               0.084
# 53                          (ex_45BitesAddon)               0.076
# 90                                (2HotWings)               0.070
# 41                   (Fries, ex_45BitesAddon)               0.097
# 101  (Fries, ex_45BitesAddon, DrumstickKent.)               0.097
# 38                                (2HotWings)               0.083
# 5                           (ex_45BitesAddon)               0.097
# 33          (DrumstickKent., ex_45BitesAddon)               0.097
#
#      consequent support  support  confidence   lift  leverage  conviction
# 98                0.083    0.070       0.985 11.927     0.065      62.047
# 93                0.072    0.070       0.853 11.927     0.065       6.318
# 99                0.071    0.070       0.839 11.897     0.065       5.764
# 92                0.084    0.070       0.999 11.897     0.065    1737.724
# 30                0.084    0.071       0.999 11.895     0.065    1410.298
# 31                0.072    0.071       0.851 11.895     0.065       6.222
# 97                0.071    0.070       0.827 11.565     0.064       5.356
# 94                0.085    0.070       0.986 11.565     0.064      64.670
# 40                0.085    0.083       0.983 11.535     0.075      54.562
# 39                0.084    0.083       0.969 11.535     0.075      29.614
# 96                0.084    0.070       0.921 10.966     0.064      11.638
# 95                0.076    0.070       0.839 10.966     0.064       5.727
# 54                0.076    0.070       0.839 10.966     0.064       5.727
# 53                0.084    0.070       0.921 10.966     0.064      11.638
# 90                0.097    0.070       1.000 10.295     0.064         inf
# 41                0.083    0.083       0.850 10.295     0.075       6.135
# 101               0.070    0.070       0.725 10.295     0.064       3.386
# 38                0.097    0.083       1.000 10.295     0.075         inf
# 5                 0.084    0.084       0.865 10.295     0.076       6.783
# 33                0.071    0.071       0.736 10.295     0.065       3.515

# %%
rules.sort_values('lift', ascending=False).head(20)
# Out:
#                                       antecedents  \
# 67                               (Fries, iTwistB)
# 68                             (mMiniTwistBsmart)
# 73                                (mLongerBsmart)
# 70                                (Fries, Longer)
# 69                                      (iTwistB)
# 66                      (mMiniTwistBsmart, Fries)
# 12                             (mMiniTwistBsmart)
# 13                                      (iTwistB)
# 154             (DrumstickKent., ex_45BitesAddon)
# 134                       (app_bucketfor1, Fries)
# 156                      (Fries, ex_45BitesAddon)
# 135              (app_bucketfor1, DrumstickKent.)
# 133             (DrumstickKent., ex_45BitesAddon)
# 132                      (Fries, ex_45BitesAddon)
# 149           (Fries, ex_45BitesAddon, 2HotWings)
# 151   (app_bucketfor1, DrumstickKent., 2HotWings)
# 158              (app_bucketfor1, DrumstickKent.)
# 146  (DrumstickKent., ex_45BitesAddon, 2HotWings)
# 161                       (app_bucketfor1, Fries)
# 153            (app_bucketfor1, Fries, 2HotWings)
#
#                                       consequents  antecedent support  \
# 67                             (mMiniTwistBsmart)               0.075
# 68                               (Fries, iTwistB)               0.075
# 73                                (Fries, Longer)               0.075
# 70                                (mLongerBsmart)               0.077
# 69                      (mMiniTwistBsmart, Fries)               0.082
# 66                                      (iTwistB)               0.073
# 12                                      (iTwistB)               0.075
# 13                             (mMiniTwistBsmart)               0.082
# 154            (app_bucketfor1, Fries, 2HotWings)               0.071
# 134             (DrumstickKent., ex_45BitesAddon)               0.083
# 156   (app_bucketfor1, DrumstickKent., 2HotWings)               0.083
# 135                      (Fries, ex_45BitesAddon)               0.071
# 133                       (app_bucketfor1, Fries)               0.071
# 132              (app_bucketfor1, DrumstickKent.)               0.083
# 149              (app_bucketfor1, DrumstickKent.)               0.083
# 151                      (Fries, ex_45BitesAddon)               0.071
# 158           (Fries, ex_45BitesAddon, 2HotWings)               0.071
# 146                       (app_bucketfor1, Fries)               0.071
# 161  (DrumstickKent., ex_45BitesAddon, 2HotWings)               0.083
# 153             (DrumstickKent., ex_45BitesAddon)               0.083
#
#      consequent support  support  confidence   lift  leverage  conviction
# 67                0.075    0.073       0.971 12.919     0.067      31.416
# 68                0.075    0.073       0.967 12.919     0.067      27.871
# 73                0.077    0.073       0.970 12.573     0.067      31.125
# 70                0.075    0.073       0.949 12.573     0.067      18.025
# 69                0.073    0.073       0.889 12.168     0.067       8.331
# 66                0.082    0.073       0.994 12.168     0.067     165.279
# 12                0.082    0.075       0.993 12.150     0.068     130.600
# 13                0.075    0.075       0.913 12.150     0.068      10.605
# 154               0.083    0.070       0.986 11.935     0.065      64.856
# 134               0.071    0.070       0.853 11.935     0.065       6.318
# 156               0.071    0.070       0.853 11.935     0.065       6.318
# 135               0.083    0.070       0.986 11.935     0.065      64.856
# 133               0.083    0.070       0.986 11.935     0.065      64.856
# 132               0.071    0.070       0.853 11.935     0.065       6.318
# 149               0.071    0.070       0.853 11.935     0.065       6.318
# 151               0.083    0.070       0.986 11.935     0.065      64.856
# 158               0.083    0.070       0.986 11.935     0.065      64.856
# 146               0.083    0.070       0.986 11.935     0.065      64.856
# 161               0.071    0.070       0.853 11.935     0.065       6.318
# 153               0.071    0.070       0.853 11.935     0.065       6.318

# %% [markdown]
# ### Conclusion
# - Looks like association analysis gives blurry image of the situation due to the obvious patterns that are very frequent:
#         - Bsmart: Fries, some main (longer, 2strips, iTwistB)
#         - app_bucketfor1: ex_45BitesAddon, app_bucketfor1, 2HotWings, DrumstickKent., fries,
#         - etc
# - Solution could be in removing such obvious product combinations from the data by hand

# %% [markdown]
# # Further cleaning

# %% [markdown]
# ### Filtering data
# We will fillter out less popular products and those which are no actual products.

# %%
limit = 1000
val_counts = data['Product'].value_counts()
less_popular_products = list(val_counts[val_counts < limit].index)
val_to_filter = ['Customer'] + less_popular_products

# %%
len(val_counts)
# Out:
# 585

# %%
data_prod_filtered = data[~data['Product'].isin(val_to_filter)]

# %%
# Standard sets
{
'Bsmart': ['mStripsBsmart', 'mMiniTwistBsmart', 'mLongerBsmart', 'Fries', '2Strips', 'Longer', 'iTwistB']
'app_bucketfor1': ['DrumstickKent.','2HotWings','ex_45BitesAddon', 'Fries']
    
}
