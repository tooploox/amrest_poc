# %% [markdown]
# # Market Basket Analysis - 'Product' level

# %% [markdown]
# Based on https://github.com/chris1610/pbpython/blob/master/notebooks/Market_Basket_Intro.ipynb

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %matplotlib inline

# %% [markdown]
# ## Load sales data

# %%
def load_sales_data():
    hours = ['0'+str(x)+':00' if x < 10 else str(x)+':00' for x in range(24)]
    hour_type = pd.CategoricalDtype(categories=hours, ordered=True)

    dtype={'GUESTCHECKID': object,
           'Date': str,
           'HourName': hour_type,
           'QuarterName': "category",
           'Product': "category",
           'FamilyGroup': "category",
           'MajorGroup': "category",
           'MPK': object,
           'Restaurant': object,
           'LocationType': "category",
           'Concept': "category",
           'ItemType': "category",
           'ComboMealNum': np.float64,
           'ile_razy': np.float64,
           'SalesChannel': "category"
           }
    parse_dates = ['Date']

    data = pd.read_csv(os.path.join(os.environ['DATA_PATH'],
                                    'kiosk_produkty/KIOSK_Produkty.csv'),
                       delimiter=";", thousands=',',
                       dtype=dtype,
                       parse_dates=parse_dates)
    return data

# %%
# %%time
data = load_sales_data()
# Out:
# CPU times: user 1min 10s, sys: 6.06 s, total: 1min 16s
# Wall time: 1min 17s

# %% [markdown]
# ## Analysis - 'Product' level
# We will create baskets of individual products and see if we can find some interesing relationships.

# %% [markdown]
# ### Prepare basket data

# %%
# https://github.com/pandas-dev/pandas/issues/19136#issuecomment-380908428
def reset_index(df):
    '''Returns DataFrame with index as columns'''
    index_df = df.index.to_frame(index=False)
    df = df.reset_index(drop=True)
    #  In merge is important the order in which you pass the dataframes
    # if the index contains a Categorical. 
    # pd.merge(df, index_df, left_index=True, right_index=True) does not work
    return pd.merge(index_df, df, left_index=True, right_index=True)


# Convert the units to 1 hot encoded values
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1


def create_basket_sets(data, variable):
    
    basket = (data.groupby(['GUESTCHECKID', variable])['ile_razy']
          .sum().unstack())
    
    basket = reset_index(basket).fillna(0).set_index('GUESTCHECKID').applymap(encode_units)
    
    basket_sets = basket.applymap(encode_units)
    
    return basket_sets

# %%
# %%time
basket_sets = create_basket_sets(data, 'Product')

# %%
# %%time
basket_sets.to_csv(os.path.join(os.environ['DATA_PATH'], 'basket_sets/basket_sets_product.csv'))
# Out:
# CPU times: user 24min 32s, sys: 5.11 s, total: 24min 38s
# Wall time: 24min 46s

# %% [markdown]
# ### Load data

# %%
# %%time
basket_sets = pd.read_csv(os.path.join(os.environ['DATA_PATH'], 'basket_sets/basket_sets_product.csv'), index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# CPU times: user 2min 24s, sys: 14.7 s, total: 2min 38s
# Wall time: 2min 39s

# %%
basket_sets = basket_sets.drop(columns=['Customer'])

# %%
basket_sets.head()
# Out:
#               10HotWings  10Strips  10xCOBHS  10xCOBKent  10xHotWings  \
# GUESTCHECKID
# 1000000246             0         0         0           0            0
# 1000000247             0         0         0           0            0
# 1000000406             0         0         0           0            0
# 1000000415             0         1         0           0            0
# 1000000416             0         0         0           0            0
#
#               10xStripsHS  11HotWings  11Strips  12xHotWings  12xStripsHS  \
# GUESTCHECKID
# 1000000246              0           0         0            0            0
# 1000000247              0           0         0            0            0
# 1000000406              0           0         0            0            0
# 1000000415              0           0         0            0            0
# 1000000416              0           0         0            0            0
#
#               ...  Zinger_wege  app_2xCheesburg  app_2xSmallCoff  \
# GUESTCHECKID  ...
# 1000000246    ...            0                0                0
# 1000000247    ...            0                0                0
# 1000000406    ...            0                0                0
# 1000000415    ...            0                0                0
# 1000000416    ...            0                0                0
#
#               app_Bites&Fries  Halloumi  TwisteHaluBox  TwisteHalum  \
# GUESTCHECKID
# 1000000246                  0         0              0            0
# 1000000247                  0         0              0            0
# 1000000406                  0         0              0            0
# 1000000415                  0         0              0            0
# 1000000416                  0         0              0            0
#
#               mHalloumi  mHalloumiBox  mTwisteHalum
# GUESTCHECKID
# 1000000246            0             0             0
# 1000000247            0             0             0
# 1000000406            0             0             0
# 1000000415            0             0             0
# 1000000416            0             0             0
#
# [5 rows x 584 columns]

# %% [markdown]
# ### Create basket rules

# %%
def analyze_basket(basket_sets):
    # Build up the frequent items
    frequent_itemsets = apriori(basket_sets, min_support=0.005, use_colnames=True)
    
    display(frequent_itemsets.sort_values('support', ascending=False).head(25))
    
    # Create the rules
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
    
    return rules

# %%
# %%time
rules = analyze_basket(basket_sets)

# %% [markdown]
# ### Explore basket rules

# %% [markdown]
# #### Metric explanations
# - Say, that lift for an association rule “if Toast then Coffee” is 1.48 because the confidence is 70%. This means that consumers who purchase Toast are 1.48 times more likely to purchase Coffee than randomly chosen customers. Larger lift means more interesting rules. Association rules with high support are potentially interesting rules. Similarly, rules with high confidence would be interesting rules as well.

# %%
rules_sic = rules[~rules['consequents'].astype(str).str.contains(',', regex=False)]
print(f"Total number of rules found: {len(rules)} Number of rules with single item consequents: {len(rules_sic)} ")
rules = rules_sic

# %%
rules = rules[~(rules['consequents'].astype(str).str.contains('Fries', regex=False) |
                rules['consequents'].astype(str).str.contains('LargeFries', regex=False) |
                rules['consequents'].astype(str).str.contains('PepsiRefill', regex=False)
               )]

# %%
rules.query('4 >lift > 1.2 and confidence > 0.3').sort_values('lift', ascending=False).head(300)

# %% [markdown]
# ### Remove standard sets - related associations
# Example: If someone buys Bsmart then we expect fries or sandwitch to be in the basket too.
#
# Those kinds of associations are not interesting and we will remove them.

# %%
def phrase_filter(rules, phrase):
    rows_w_phrase = (rules['antecedents'].astype(str).str.contains(phrase, regex=False) | rules['consequents'].astype(str).str.contains(phrase, regex=False))
    
    return (rows_w_phrase)

# %%
len(rules)
# Out:
# 8996

# %%
fillter = (~phrase_filter(rules, 'Bsmart') & ~phrase_filter(rules, 'app_bucketfor1') & ~phrase_filter(rules, 'ex_45BitesAddon'))
display(len(rules[fillter]))
rules[fillter].sort_values('lift', ascending=False).head(50)
# Out:
# 6070
#                                             antecedents  \
# 6304                     (DipMajoGarlic, 8Strips (new))
# 6301                  (8HotWings, 2ChickenKent., Fries)
# 8420                     (DipMajoGarlic, 8Strips (new))
# 8397  (8HotWings, mClassicBucketXL, 2ChickenKent., F...
# 6302          (8HotWings, DipMajoGarlic, 2ChickenKent.)
# 6303                             (8Strips (new), Fries)
# 8419                             (8Strips (new), Fries)
# 8398  (8HotWings, DipMajoGarlic, mClassicBucketXL, 2...
# 7815                             (8Strips (new), Fries)
# 7814       (8HotWings, DipMajoGarlic, mClassicBucketXL)
# 8401                  (8HotWings, 8Strips (new), Fries)
# 8416   (DipMajoGarlic, mClassicBucketXL, 2ChickenKent.)
# 8404          (8HotWings, DipMajoGarlic, 8Strips (new))
# 8413           (mClassicBucketXL, 2ChickenKent., Fries)
# 6421           (mClassicBucketXL, 2ChickenKent., Fries)
# 6424                     (DipMajoGarlic, 8Strips (new))
# 6422   (DipMajoGarlic, mClassicBucketXL, 2ChickenKent.)
# 6423                             (8Strips (new), Fries)
# 7807                  (8HotWings, 8Strips (new), Fries)
# 7822                  (DipMajoGarlic, mClassicBucketXL)
# 4974                  (mClassicBucketXL, DipMajoGarlic)
# 4975                             (8Strips (new), Fries)
# 6332       (8HotWings, mClassicBucketXL, 2ChickenKent.)
# 6333                     (DipMajoGarlic, 8Strips (new))
# 6313                                    (8Strips (new))
# 6292   (8HotWings, DipMajoGarlic, 2ChickenKent., Fries)
# 8418       (8HotWings, mClassicBucketXL, 2ChickenKent.)
# 8399              (DipMajoGarlic, 8Strips (new), Fries)
# 7804  (8HotWings, DipMajoGarlic, mClassicBucketXL, F...
# 7825                                    (8Strips (new))
# 7816                     (DipMajoGarlic, 8Strips (new))
# 7813               (8HotWings, mClassicBucketXL, Fries)
# 8383  (Fries, DipMajoGarlic, mClassicBucketXL, 8HotW...
# 8434                                    (8Strips (new))
# 4924                                    (8Strips (new))
# 4913       (8HotWings, mClassicBucketXL, DipMajoGarlic)
# 3143                                    (8Strips (new))
# 3130          (8HotWings, DipMajoGarlic, 2ChickenKent.)
# 6322  (8HotWings, DipMajoGarlic, mClassicBucketXL, 2...
# 6343                                    (8Strips (new))
# 8395  (DipMajoGarlic, mClassicBucketXL, 2ChickenKent...
# 8422                         (8HotWings, 8Strips (new))
# 6330   (DipMajoGarlic, mClassicBucketXL, 2ChickenKent.)
# 6335                         (8HotWings, 8Strips (new))
# 6293              (DipMajoGarlic, 8Strips (new), Fries)
# 6312                         (8HotWings, 2ChickenKent.)
# 7811           (DipMajoGarlic, mClassicBucketXL, Fries)
# 7818                         (8HotWings, 8Strips (new))
# 3138                     (DipMajoGarlic, 8Strips (new))
# 3135                         (8HotWings, 2ChickenKent.)
#
#                                             consequents  antecedent support  \
# 6304                  (8HotWings, 2ChickenKent., Fries)               0.006
# 6301                     (DipMajoGarlic, 8Strips (new))               0.006
# 8420  (8HotWings, mClassicBucketXL, 2ChickenKent., F...               0.006
# 8397                     (DipMajoGarlic, 8Strips (new))               0.006
# 6302                             (8Strips (new), Fries)               0.006
# 6303          (8HotWings, DipMajoGarlic, 2ChickenKent.)               0.007
# 8419  (8HotWings, DipMajoGarlic, mClassicBucketXL, 2...               0.007
# 8398                             (8Strips (new), Fries)               0.005
# 7815       (8HotWings, DipMajoGarlic, mClassicBucketXL)               0.007
# 7814                             (8Strips (new), Fries)               0.006
# 8401   (DipMajoGarlic, mClassicBucketXL, 2ChickenKent.)               0.007
# 8416                  (8HotWings, 8Strips (new), Fries)               0.005
# 8404           (mClassicBucketXL, 2ChickenKent., Fries)               0.006
# 8413          (8HotWings, DipMajoGarlic, 8Strips (new))               0.006
# 6421                     (DipMajoGarlic, 8Strips (new))               0.006
# 6424           (mClassicBucketXL, 2ChickenKent., Fries)               0.006
# 6422                             (8Strips (new), Fries)               0.005
# 6423   (DipMajoGarlic, mClassicBucketXL, 2ChickenKent.)               0.007
# 7807                  (DipMajoGarlic, mClassicBucketXL)               0.007
# 7822                  (8HotWings, 8Strips (new), Fries)               0.006
# 4974                             (8Strips (new), Fries)               0.006
# 4975                  (mClassicBucketXL, DipMajoGarlic)               0.007
# 6332                     (DipMajoGarlic, 8Strips (new))               0.006
# 6333       (8HotWings, mClassicBucketXL, 2ChickenKent.)               0.006
# 6313   (8HotWings, DipMajoGarlic, 2ChickenKent., Fries)               0.007
# 6292                                    (8Strips (new))               0.006
# 8418              (DipMajoGarlic, 8Strips (new), Fries)               0.006
# 8399       (8HotWings, mClassicBucketXL, 2ChickenKent.)               0.006
# 7804                                    (8Strips (new))               0.006
# 7825  (8HotWings, DipMajoGarlic, mClassicBucketXL, F...               0.007
# 7816               (8HotWings, mClassicBucketXL, Fries)               0.006
# 7813                     (DipMajoGarlic, 8Strips (new))               0.006
# 8383                                    (8Strips (new))               0.005
# 8434  (Fries, DipMajoGarlic, mClassicBucketXL, 8HotW...               0.007
# 4924       (8HotWings, mClassicBucketXL, DipMajoGarlic)               0.007
# 4913                                    (8Strips (new))               0.006
# 3143          (8HotWings, DipMajoGarlic, 2ChickenKent.)               0.007
# 3130                                    (8Strips (new))               0.006
# 6322                                    (8Strips (new))               0.005
# 6343  (8HotWings, DipMajoGarlic, mClassicBucketXL, 2...               0.007
# 8395                         (8HotWings, 8Strips (new))               0.005
# 8422  (DipMajoGarlic, mClassicBucketXL, 2ChickenKent...               0.007
# 6330                         (8HotWings, 8Strips (new))               0.005
# 6335   (DipMajoGarlic, mClassicBucketXL, 2ChickenKent.)               0.007
# 6293                         (8HotWings, 2ChickenKent.)               0.006
# 6312              (DipMajoGarlic, 8Strips (new), Fries)               0.006
# 7811                         (8HotWings, 8Strips (new))               0.006
# 7818           (DipMajoGarlic, mClassicBucketXL, Fries)               0.007
# 3138                         (8HotWings, 2ChickenKent.)               0.006
# 3135                     (DipMajoGarlic, 8Strips (new))               0.006
#
#       consequent support  support  confidence    lift  leverage  conviction
# 6304               0.006    0.006       0.855 150.605     0.005       6.868
# 6301               0.006    0.006       0.974 150.605     0.005      37.869
# 8420               0.006    0.005       0.834 150.549     0.005       5.988
# 8397               0.006    0.005       0.973 150.549     0.005      37.356
# 6302               0.007    0.006       0.991 150.541     0.005     107.802
# 6303               0.006    0.006       0.840 150.541     0.005       6.222
# 8419               0.005    0.005       0.819 150.515     0.005       5.503
# 8398               0.007    0.005       0.991 150.515     0.005     105.818
# 7815               0.006    0.006       0.955 150.511     0.006      22.145
# 7814               0.007    0.006       0.991 150.511     0.006     105.551
# 8401               0.005    0.005       0.820 150.491     0.005       5.514
# 8416               0.007    0.005       0.990 150.491     0.005      99.427
# 8404               0.006    0.005       0.834 150.478     0.005       5.998
# 8413               0.006    0.005       0.973 150.478     0.005      36.322
# 6421               0.006    0.005       0.973 150.460     0.005      36.562
# 6424               0.006    0.005       0.834 150.460     0.005       5.994
# 6422               0.007    0.005       0.990 150.451     0.005     101.279
# 6423               0.005    0.005       0.819 150.451     0.005       5.507
# 7807               0.006    0.006       0.956 150.446     0.006      22.361
# 7822               0.007    0.006       0.990 150.446     0.006      96.528
# 4974               0.007    0.006       0.990 150.425     0.006      99.560
# 4975               0.006    0.006       0.955 150.425     0.006      22.295
# 6332               0.006    0.005       0.973 150.413     0.005      36.159
# 6333               0.006    0.005       0.839 150.413     0.005       6.183
# 6313               0.006    0.006       0.834 150.401     0.005       5.998
# 6292               0.007    0.006       0.997 150.401     0.005     325.592
# 8418               0.006    0.005       0.966 150.401     0.005      29.620
# 8399               0.006    0.005       0.839 150.401     0.005       6.180
# 7804               0.007    0.006       0.997 150.401     0.006     325.466
# 7825               0.006    0.006       0.948 150.401     0.006      19.236
# 7816               0.006    0.006       0.972 150.392     0.006      35.786
# 7813               0.006    0.006       0.972 150.392     0.006      35.980
# 8383               0.007    0.005       0.997 150.389     0.005     317.509
# 8434               0.005    0.005       0.813 150.389     0.005       5.331
# 4924               0.006    0.006       0.954 150.388     0.006      21.766
# 4913               0.007    0.006       0.997 150.388     0.006     316.637
# 3143               0.006    0.006       0.839 150.386     0.006       6.189
# 3130               0.007    0.006       0.997 150.386     0.006     315.255
# 6322               0.007    0.005       0.997 150.383     0.005     313.370
# 6343               0.005    0.005       0.819 150.383     0.005       5.481
# 8395               0.007    0.005       0.996 150.374     0.005     270.032
# 8422               0.005    0.005       0.814 150.374     0.005       5.342
# 6330               0.007    0.005       0.996 150.359     0.005     262.988
# 6335               0.005    0.005       0.819 150.359     0.005       5.492
# 6293               0.006    0.006       0.861 150.352     0.005       7.129
# 6312               0.006    0.006       0.966 150.352     0.005      29.346
# 7811               0.007    0.006       0.996 150.342     0.006     255.311
# 7818               0.006    0.006       0.949 150.342     0.006      19.396
# 3138               0.006    0.006       0.860 150.341     0.006       7.126
# 3135               0.006    0.006       0.972 150.341     0.006      35.555

# %% [markdown]
# #### Conclusions
# - Looks like association analysis gives blurry image of the situation due to the obvious patterns that are very frequent:
#         - Bsmart: Fries, some main (longer, 2strips, iTwistB)
#         - app_bucketfor1: ex_45BitesAddon, app_bucketfor1, 2HotWings, DrumstickKent., fries,
#         - etc
# - Solution could be in removing such obvious product combinations from the data by hand

# %% [markdown]
# ### TODO:  Filtering data
# We will fillter out less popular products and those which are no actual products.

# %%
limit = 1000
val_counts = data['Product'].value_counts()
less_popular_products = list(val_counts[val_counts < limit].index)
val_to_filter = ['Customer'] + less_popular_products

# %%
len(val_counts)
# Out:
# 585

# %%
data_prod_filtered = data[~data['Product'].isin(val_to_filter)]

# %%
# Standard sets
{'Bsmart': ['mStripsBsmart', 'mMiniTwistBsmart', 'mLongerBsmart', 'Fries', '2Strips', 'Longer', 'iTwistB'],
'app_bucketfor1': ['DrumstickKent.','2HotWings','ex_45BitesAddon', 'Fries']
}
# Out:
# {'Bsmart': ['mStripsBsmart',
#   'mMiniTwistBsmart',
#   'mLongerBsmart',
#   'Fries',
#   '2Strips',
#   'Longer',
#   'iTwistB'],
#  'app_bucketfor1': ['DrumstickKent.', '2HotWings', 'ex_45BitesAddon', 'Fries']}

# %% [markdown]
# ## Analysis - 'FamilyGroup' level

# %%
# Delete unnecesary data and save memory
del basket_sets

# %% [markdown]
# ### Prepare basket data

# %%
# %%time
basket_sets = create_basket_sets(data, 'FamilyGroup')
# Out:
# CPU times: user 51.9 s, sys: 420 ms, total: 52.4 s
# Wall time: 52.5 s

# %%
# %%time
basket_sets.to_csv(os.path.join(os.environ['DATA_PATH'], 'basket_sets/basket_sets_familygroup.csv'))
# Out:
# CPU times: user 47.5 s, sys: 216 ms, total: 47.7 s
# Wall time: 48.2 s

# %%
# %%time
# Load data (if prepared before)
basket_sets = pd.read_csv(os.path.join(os.environ['DATA_PATH'], 'basket_sets/basket_sets_familygroup.csv'), index_col=0)
# Out:
# CPU times: user 2.41 s, sys: 24 ms, total: 2.44 s
# Wall time: 2.44 s

# %%
basket_sets.head()
# Out:
#               Box  Bucket  Burgers & Sandwiches  Chicken  Cold Beverages  \
# GUESTCHECKID
# 1000000246      0       0                     0        1               0
# 1000000247      0       0                     0        0               0
# 1000000406      0       0                     1        0               0
# 1000000415      0       1                     0        1               1
# 1000000416      0       0                     1        0               0
#
#               Condiments  Desserts  Hot Beverages  Menus  Promos  Salads  \
# GUESTCHECKID
# 1000000246             0         0              0      0       1       0
# 1000000247             0         0              0      0       1       0
# 1000000406             0         0              0      0       1       0
# 1000000415             0         0              0      0       1       0
# 1000000416             0         0              0      0       1       0
#
#               Sides  Value  Coupons  Breakfast  LSM
# GUESTCHECKID
# 1000000246        1      0        1          0    0
# 1000000247        1      0        0          0    0
# 1000000406        0      0        1          0    0
# 1000000415        1      0        0          0    0
# 1000000416        1      1        0          0    0

# %% [markdown]
# ### Create basket rules

# %%
# %%time
rules = analyze_basket(basket_sets)
# Out:
#     support                                           itemsets
# 8     0.998                                           (Promos)
# 9     0.752                                            (Sides)
# 38    0.750                                    (Sides, Promos)
# 2     0.641                             (Burgers & Sandwiches)
# 22    0.640                     (Promos, Burgers & Sandwiches)
# 23    0.495                      (Sides, Burgers & Sandwiches)
# 59    0.494              (Sides, Promos, Burgers & Sandwiches)
# 3     0.443                                          (Chicken)
# 27    0.442                                  (Chicken, Promos)
# 28    0.408                                   (Sides, Chicken)
# 66    0.408                           (Sides, Promos, Chicken)
# 4     0.352                                   (Cold Beverages)
# 32    0.351                           (Promos, Cold Beverages)
# 10    0.312                                            (Value)
# 39    0.312                                    (Promos, Value)
# 33    0.312                            (Sides, Cold Beverages)
# 73    0.311                    (Sides, Promos, Cold Beverages)
# 41    0.304                                     (Sides, Value)
# 75    0.303                             (Sides, Promos, Value)
# 19    0.258             (Burgers & Sandwiches, Cold Beverages)
# 54    0.258     (Promos, Burgers & Sandwiches, Cold Beverages)
# 55    0.240      (Sides, Burgers & Sandwiches, Cold Beverages)
# 86    0.240  (Sides, Promos, Burgers & Sandwiches, Cold Bev...
# 24    0.234                      (Burgers & Sandwiches, Value)
# 60    0.233              (Promos, Burgers & Sandwiches, Value)
# CPU times: user 6.21 s, sys: 8 ms, total: 6.22 s
# Wall time: 6.28 s

# %% [markdown]
# ### Explore basket rules

# %%
basket_sets.columns.values
# Out:
# array(['Box', 'Bucket', 'Burgers & Sandwiches', 'Chicken',
#        'Cold Beverages', 'Condiments', 'Desserts', 'Hot Beverages',
#        'Menus', 'Promos', 'Salads', 'Sides', 'Value', 'Coupons',
#        'Breakfast', 'LSM'], dtype=object)

# %%
len(rules)
# Out:
# 472

# %%
pd.set_option('display.max_rows', 300)
fillter = (~phrase_filter(rules, 'Promos'))
rules[fillter].sort_values('lift', ascending=False)
# Out:
#                                          antecedents  \
# 308                                          (Menus)
# 297    (Sides, Burgers & Sandwiches, Cold Beverages)
# 59                           (Sides, Cold Beverages)
# 62                                             (Box)
# 304           (Burgers & Sandwiches, Cold Beverages)
# 301                                   (Sides, Menus)
# 100                                          (Menus)
# 97            (Burgers & Sandwiches, Cold Beverages)
# 303                    (Burgers & Sandwiches, Menus)
# 302                          (Sides, Cold Beverages)
# 198                                          (Menus)
# 195                          (Sides, Cold Beverages)
# 63                                  (Cold Beverages)
# 58                                      (Sides, Box)
# 0                                              (Box)
# 1                                   (Cold Beverages)
# 296             (Sides, Burgers & Sandwiches, Menus)
# 309                                 (Cold Beverages)
# 96                     (Burgers & Sandwiches, Menus)
# 101                                 (Cold Beverages)
# 199                                 (Cold Beverages)
# 194                                   (Sides, Menus)
# 32                                           (Menus)
# 33                                  (Cold Beverages)
# 6                                          (Chicken)
# 7                                           (Bucket)
# 80                                         (Chicken)
# 77                                   (Sides, Bucket)
# 81                                          (Bucket)
# 76                                  (Sides, Chicken)
# 260                  (Chicken, Burgers & Sandwiches)
# 259                          (Sides, Cold Beverages)
# 300                    (Sides, Burgers & Sandwiches)
# 305                          (Menus, Cold Beverages)
# 256           (Sides, Chicken, Burgers & Sandwiches)
# 263                                 (Cold Beverages)
# 88                   (Chicken, Burgers & Sandwiches)
# 89                                  (Cold Beverages)
# 131                                          (Menus)
# 126                    (Sides, Burgers & Sandwiches)
# 145                                          (Value)
# 140                    (Sides, Burgers & Sandwiches)
# 15                            (Burgers & Sandwiches)
# 14                                      (Condiments)
# 186                                        (Chicken)
# 183                                 (Sides, Coupons)
# 274           (Sides, Chicken, Burgers & Sandwiches)
# 281                                          (Value)
# 108                    (Sides, Burgers & Sandwiches)
# 113                                 (Cold Beverages)
# 277                                   (Sides, Value)
# 278                  (Chicken, Burgers & Sandwiches)
# 298                   (Sides, Menus, Cold Beverages)
# 307                           (Burgers & Sandwiches)
# 94                   (Chicken, Burgers & Sandwiches)
# 95                                           (Value)
# 99                            (Burgers & Sandwiches)
# 98                           (Menus, Cold Beverages)
# 142                    (Burgers & Sandwiches, Value)
# 143                                          (Sides)
# 185                                          (Sides)
# 184                               (Chicken, Coupons)
# 306                                          (Sides)
# 299    (Burgers & Sandwiches, Menus, Cold Beverages)
# 60                             (Box, Cold Beverages)
# 61                                           (Sides)
# 196                          (Menus, Cold Beverages)
# 197                                          (Sides)
# 129                                          (Sides)
# 128                    (Burgers & Sandwiches, Menus)
# 43                                           (Menus)
# 42                                           (Sides)
# 5                                              (Box)
# 4                                            (Sides)
# 280                                          (Sides)
# 275           (Chicken, Burgers & Sandwiches, Value)
# 187                                        (Coupons)
# 182                                 (Sides, Chicken)
# 262                                          (Sides)
# 257  (Chicken, Burgers & Sandwiches, Cold Beverages)
# 49                                           (Value)
# 48                                           (Sides)
# 127                                   (Sides, Menus)
# 130                           (Burgers & Sandwiches)
# 17                                           (Menus)
# 16                            (Burgers & Sandwiches)
# 157                                          (Sides)
# 156                        (Chicken, Cold Beverages)
# 93                                           (Sides)
# 92                   (Chicken, Burgers & Sandwiches)
# 178                                 (Chicken, Value)
# 179                                          (Sides)
# 110           (Burgers & Sandwiches, Cold Beverages)
# 111                                          (Sides)
# 27                                         (Chicken)
# 26                                           (Sides)
# 158                                        (Chicken)
# 155                          (Sides, Cold Beverages)
# 30                                         (Chicken)
# 31                                         (Coupons)
# 112                           (Burgers & Sandwiches)
# 109                          (Sides, Cold Beverages)
# 258                    (Sides, Burgers & Sandwiches)
# 261                        (Chicken, Cold Beverages)
# 144                           (Burgers & Sandwiches)
# 141                                   (Sides, Value)
# 36                                           (Sides)
# 37                                  (Cold Beverages)
# 154                                 (Sides, Chicken)
# 159                                 (Cold Beverages)
# 21                                           (Value)
# 20                            (Burgers & Sandwiches)
# 10                                           (Sides)
# 11                                          (Bucket)
# 78                                 (Chicken, Bucket)
# 79                                           (Sides)
# 12                            (Burgers & Sandwiches)
# 13                                  (Cold Beverages)
# 23                                  (Cold Beverages)
# 22                                         (Chicken)
# 181                                          (Value)
# 176                                 (Sides, Chicken)
# 51                                         (Coupons)
# 50                                           (Sides)
# 29                                           (Value)
# 28                                         (Chicken)
# 177                                   (Sides, Value)
# 180                                        (Chicken)
# 146                  (Coupons, Burgers & Sandwiches)
# 147                                          (Sides)
# 18                                           (Sides)
# 19                            (Burgers & Sandwiches)
# 276                    (Sides, Burgers & Sandwiches)
# 279                                 (Chicken, Value)
#
#                                          consequents  antecedent support  \
# 308    (Sides, Burgers & Sandwiches, Cold Beverages)               0.173
# 297                                          (Menus)               0.240
# 59                                             (Box)               0.312
# 62                           (Sides, Cold Beverages)               0.072
# 304                                   (Sides, Menus)               0.258
# 301           (Burgers & Sandwiches, Cold Beverages)               0.171
# 100           (Burgers & Sandwiches, Cold Beverages)               0.173
# 97                                           (Menus)               0.258
# 303                          (Sides, Cold Beverages)               0.143
# 302                    (Burgers & Sandwiches, Menus)               0.312
# 198                          (Sides, Cold Beverages)               0.173
# 195                                          (Menus)               0.312
# 63                                      (Sides, Box)               0.352
# 58                                  (Cold Beverages)               0.071
# 0                                   (Cold Beverages)               0.072
# 1                                              (Box)               0.352
# 296                                 (Cold Beverages)               0.141
# 309             (Sides, Burgers & Sandwiches, Menus)               0.352
# 96                                  (Cold Beverages)               0.143
# 101                    (Burgers & Sandwiches, Menus)               0.352
# 199                                   (Sides, Menus)               0.352
# 194                                 (Cold Beverages)               0.171
# 32                                  (Cold Beverages)               0.173
# 33                                           (Menus)               0.352
# 6                                           (Bucket)               0.443
# 7                                          (Chicken)               0.100
# 80                                   (Sides, Bucket)               0.443
# 77                                         (Chicken)               0.086
# 81                                  (Sides, Chicken)               0.100
# 76                                          (Bucket)               0.408
# 260                          (Sides, Cold Beverages)               0.182
# 259                  (Chicken, Burgers & Sandwiches)               0.312
# 300                          (Menus, Cold Beverages)               0.495
# 305                    (Sides, Burgers & Sandwiches)               0.157
# 256                                 (Cold Beverages)               0.175
# 263           (Sides, Chicken, Burgers & Sandwiches)               0.352
# 88                                  (Cold Beverages)               0.182
# 89                   (Chicken, Burgers & Sandwiches)               0.352
# 131                    (Sides, Burgers & Sandwiches)               0.173
# 126                                          (Menus)               0.495
# 145                    (Sides, Burgers & Sandwiches)               0.312
# 140                                          (Value)               0.495
# 15                                      (Condiments)               0.641
# 14                            (Burgers & Sandwiches)               0.084
# 186                                 (Sides, Coupons)               0.443
# 183                                        (Chicken)               0.186
# 274                                          (Value)               0.175
# 281           (Sides, Chicken, Burgers & Sandwiches)               0.312
# 108                                 (Cold Beverages)               0.495
# 113                    (Sides, Burgers & Sandwiches)               0.352
# 277                  (Chicken, Burgers & Sandwiches)               0.304
# 278                                   (Sides, Value)               0.182
# 298                           (Burgers & Sandwiches)               0.156
# 307                   (Sides, Menus, Cold Beverages)               0.641
# 94                                           (Value)               0.182
# 95                   (Chicken, Burgers & Sandwiches)               0.312
# 99                           (Menus, Cold Beverages)               0.641
# 98                            (Burgers & Sandwiches)               0.157
# 142                                          (Sides)               0.234
# 143                    (Burgers & Sandwiches, Value)               0.752
# 185                               (Chicken, Coupons)               0.752
# 184                                          (Sides)               0.120
# 306    (Burgers & Sandwiches, Menus, Cold Beverages)               0.752
# 299                                          (Sides)               0.136
# 60                                           (Sides)               0.072
# 61                             (Box, Cold Beverages)               0.752
# 196                                          (Sides)               0.157
# 197                          (Menus, Cold Beverages)               0.752
# 129                    (Burgers & Sandwiches, Menus)               0.752
# 128                                          (Sides)               0.143
# 43                                           (Sides)               0.173
# 42                                           (Menus)               0.752
# 5                                            (Sides)               0.072
# 4                                              (Box)               0.752
# 280           (Chicken, Burgers & Sandwiches, Value)               0.752
# 275                                          (Sides)               0.077
# 187                                 (Sides, Chicken)               0.223
# 182                                        (Coupons)               0.408
# 262  (Chicken, Burgers & Sandwiches, Cold Beverages)               0.752
# 257                                          (Sides)               0.107
# 49                                           (Sides)               0.312
# 48                                           (Value)               0.752
# 127                           (Burgers & Sandwiches)               0.171
# 130                                   (Sides, Menus)               0.641
# 17                            (Burgers & Sandwiches)               0.173
# 16                                           (Menus)               0.641
# 157                        (Chicken, Cold Beverages)               0.752
# 156                                          (Sides)               0.175
# 93                   (Chicken, Burgers & Sandwiches)               0.752
# 92                                           (Sides)               0.182
# 178                                          (Sides)               0.150
# 179                                 (Chicken, Value)               0.752
# 110                                          (Sides)               0.258
# 111           (Burgers & Sandwiches, Cold Beverages)               0.752
# 27                                           (Sides)               0.443
# 26                                         (Chicken)               0.752
# 158                          (Sides, Cold Beverages)               0.443
# 155                                        (Chicken)               0.312
# 30                                         (Coupons)               0.443
# 31                                         (Chicken)               0.223
# 112                          (Sides, Cold Beverages)               0.641
# 109                           (Burgers & Sandwiches)               0.312
# 258                        (Chicken, Cold Beverages)               0.495
# 261                    (Sides, Burgers & Sandwiches)               0.175
# 144                                   (Sides, Value)               0.641
# 141                           (Burgers & Sandwiches)               0.304
# 36                                  (Cold Beverages)               0.752
# 37                                           (Sides)               0.352
# 154                                 (Cold Beverages)               0.408
# 159                                 (Sides, Chicken)               0.352
# 21                            (Burgers & Sandwiches)               0.312
# 20                                           (Value)               0.641
# 10                                          (Bucket)               0.752
# 11                                           (Sides)               0.100
# 78                                           (Sides)               0.100
# 79                                 (Chicken, Bucket)               0.752
# 12                                  (Cold Beverages)               0.641
# 13                            (Burgers & Sandwiches)               0.352
# 23                                         (Chicken)               0.352
# 22                                  (Cold Beverages)               0.443
# 181                                 (Sides, Chicken)               0.312
# 176                                          (Value)               0.408
# 51                                           (Sides)               0.223
# 50                                         (Coupons)               0.752
# 29                                         (Chicken)               0.312
# 28                                           (Value)               0.443
# 177                                        (Chicken)               0.304
# 180                                   (Sides, Value)               0.443
# 146                                          (Sides)               0.134
# 147                  (Coupons, Burgers & Sandwiches)               0.752
# 18                            (Burgers & Sandwiches)               0.752
# 19                                           (Sides)               0.641
# 276                                 (Chicken, Value)               0.495
# 279                    (Sides, Burgers & Sandwiches)               0.150
#
#      consequent support  support  confidence  lift  leverage  conviction
# 308               0.240    0.135       0.777 3.234     0.093       3.407
# 297               0.173    0.135       0.560 3.234     0.093       1.879
# 59                0.072    0.071       0.227 3.135     0.048       1.200
# 62                0.312    0.071       0.977 3.135     0.048      29.529
# 304               0.171    0.135       0.521 3.046     0.090       1.729
# 301               0.258    0.135       0.787 3.046     0.090       3.485
# 100               0.258    0.136       0.786 3.042     0.091       3.467
# 97                0.173    0.136       0.527 3.042     0.091       1.747
# 303               0.312    0.135       0.942 3.024     0.090      11.880
# 302               0.143    0.135       0.432 3.024     0.090       1.509
# 198               0.312    0.156       0.898 2.883     0.102       6.756
# 195               0.173    0.156       0.499 2.883     0.102       1.651
# 63                0.071    0.071       0.201 2.815     0.046       1.162
# 58                0.352    0.071       0.990 2.815     0.046      63.926
# 0                 0.352    0.072       0.989 2.811     0.046      56.728
# 1                 0.072    0.072       0.203 2.811     0.046       1.164
# 296               0.352    0.135       0.954 2.713     0.085      14.166
# 309               0.141    0.135       0.383 2.713     0.085       1.391
# 96                0.352    0.136       0.953 2.710     0.086      13.839
# 101               0.143    0.136       0.387 2.710     0.086       1.399
# 199               0.171    0.156       0.442 2.587     0.095       1.486
# 194               0.352    0.156       0.910 2.587     0.095       7.196
# 32                0.352    0.157       0.909 2.586     0.097       7.158
# 33                0.173    0.157       0.448 2.586     0.097       1.497
# 6                 0.100    0.100       0.225 2.258     0.056       1.162
# 7                 0.443    0.100       1.000 2.258     0.056   33473.541
# 80                0.086    0.086       0.194 2.258     0.048       1.134
# 77                0.443    0.086       1.000 2.258     0.048   28863.800
# 81                0.408    0.086       0.862 2.111     0.045       4.295
# 76                0.100    0.086       0.210 2.111     0.045       1.140
# 260               0.312    0.104       0.571 1.832     0.047       1.604
# 259               0.182    0.104       0.334 1.832     0.047       1.228
# 300               0.157    0.135       0.272 1.728     0.057       1.157
# 305               0.495    0.135       0.854 1.728     0.057       3.471
# 256               0.352    0.104       0.594 1.690     0.042       1.598
# 263               0.175    0.104       0.296 1.690     0.042       1.172
# 88                0.352    0.107       0.586 1.666     0.043       1.566
# 89                0.182    0.107       0.304 1.666     0.043       1.174
# 131               0.495    0.141       0.814 1.646     0.055       2.721
# 126               0.173    0.141       0.285 1.646     0.055       1.157
# 145               0.495    0.232       0.744 1.504     0.078       1.974
# 140               0.312    0.232       0.470 1.504     0.078       1.297
# 15                0.084    0.078       0.122 1.460     0.025       1.044
# 14                0.641    0.078       0.936 1.460     0.025       5.627
# 186               0.186    0.119       0.269 1.450     0.037       1.114
# 183               0.443    0.119       0.642 1.450     0.037       1.557
# 274               0.312    0.076       0.432 1.384     0.021       1.211
# 281               0.175    0.076       0.242 1.384     0.021       1.089
# 108               0.352    0.240       0.486 1.381     0.066       1.261
# 113               0.495    0.240       0.683 1.381     0.066       1.595
# 277               0.182    0.076       0.249 1.366     0.020       1.089
# 278               0.304    0.076       0.415 1.366     0.020       1.190
# 298               0.641    0.135       0.865 1.349     0.035       2.658
# 307               0.156    0.135       0.210 1.349     0.035       1.069
# 94                0.312    0.077       0.421 1.348     0.020       1.188
# 95                0.182    0.077       0.246 1.348     0.020       1.084
# 99                0.157    0.136       0.212 1.348     0.035       1.069
# 98                0.641    0.136       0.864 1.348     0.035       2.644
# 142               0.752    0.232       0.994 1.323     0.057      44.263
# 143               0.234    0.232       0.309 1.323     0.057       1.109
# 185               0.120    0.119       0.159 1.319     0.029       1.046
# 184               0.752    0.119       0.992 1.319     0.029      29.641
# 306               0.136    0.135       0.179 1.315     0.032       1.052
# 299               0.752    0.135       0.988 1.315     0.032      21.294
# 60                0.752    0.071       0.988 1.314     0.017      20.636
# 61                0.072    0.071       0.094 1.314     0.017       1.025
# 196               0.752    0.156       0.988 1.313     0.037      19.914
# 197               0.157    0.156       0.207 1.313     0.037       1.062
# 129               0.143    0.141       0.188 1.313     0.034       1.055
# 128               0.752    0.141       0.987 1.313     0.034      19.427
# 43                0.752    0.171       0.987 1.313     0.041      19.120
# 42                0.173    0.171       0.227 1.313     0.041       1.070
# 5                 0.752    0.071       0.987 1.312     0.017      18.645
# 4                 0.072    0.071       0.095 1.312     0.017       1.025
# 280               0.077    0.076       0.101 1.311     0.018       1.027
# 275               0.752    0.076       0.986 1.311     0.018      17.478
# 187               0.408    0.119       0.535 1.310     0.028       1.272
# 182               0.223    0.119       0.292 1.310     0.028       1.098
# 262               0.107    0.104       0.138 1.295     0.024       1.037
# 257               0.752    0.104       0.974 1.295     0.024       9.537
# 49                0.752    0.304       0.972 1.293     0.069       8.994
# 48                0.312    0.304       0.404 1.293     0.069       1.154
# 127               0.641    0.141       0.825 1.286     0.031       2.048
# 130               0.171    0.141       0.220 1.286     0.031       1.063
# 17                0.641    0.143       0.825 1.286     0.032       2.046
# 16                0.173    0.143       0.223 1.286     0.032       1.064
# 157               0.175    0.169       0.224 1.282     0.037       1.064
# 156               0.752    0.169       0.964 1.282     0.037       6.869
# 93                0.182    0.175       0.233 1.277     0.038       1.066
# 92                0.752    0.175       0.960 1.277     0.038       6.230
# 178               0.752    0.143       0.953 1.267     0.030       5.234
# 179               0.150    0.143       0.190 1.267     0.030       1.050
# 110               0.752    0.240       0.929 1.236     0.046       3.519
# 111               0.258    0.240       0.320 1.236     0.046       1.090
# 27                0.752    0.408       0.922 1.226     0.075       3.185
# 26                0.443    0.408       0.543 1.226     0.075       1.220
# 158               0.312    0.169       0.381 1.223     0.031       1.112
# 155               0.443    0.169       0.542 1.223     0.031       1.215
# 30                0.223    0.120       0.271 1.218     0.022       1.067
# 31                0.443    0.120       0.540 1.218     0.022       1.210
# 112               0.312    0.240       0.374 1.202     0.040       1.101
# 109               0.641    0.240       0.771 1.202     0.040       1.567
# 258               0.175    0.104       0.210 1.202     0.017       1.045
# 261               0.495    0.104       0.594 1.202     0.017       1.246
# 144               0.304    0.232       0.362 1.193     0.038       1.092
# 141               0.641    0.232       0.765 1.193     0.038       1.526
# 36                0.352    0.312       0.414 1.178     0.047       1.107
# 37                0.752    0.312       0.886 1.178     0.047       2.173
# 154               0.352    0.169       0.413 1.174     0.025       1.105
# 159               0.408    0.169       0.480 1.174     0.025       1.137
# 21                0.641    0.234       0.748 1.166     0.033       1.424
# 20                0.312    0.234       0.364 1.166     0.033       1.082
# 10                0.100    0.086       0.114 1.147     0.011       1.017
# 11                0.752    0.086       0.862 1.147     0.011       1.802
# 78                0.752    0.086       0.862 1.147     0.011       1.802
# 79                0.100    0.086       0.114 1.147     0.011       1.017
# 12                0.352    0.258       0.403 1.146     0.033       1.086
# 13                0.641    0.258       0.735 1.146     0.033       1.352
# 23                0.443    0.175       0.498 1.124     0.019       1.109
# 22                0.352    0.175       0.395 1.124     0.019       1.072
# 181               0.408    0.143       0.458 1.121     0.015       1.091
# 176               0.312    0.143       0.350 1.121     0.015       1.058
# 51                0.752    0.186       0.833 1.108     0.018       1.486
# 50                0.223    0.186       0.247 1.108     0.018       1.032
# 29                0.443    0.150       0.481 1.085     0.012       1.072
# 28                0.312    0.150       0.339 1.085     0.012       1.040
# 177               0.443    0.143       0.471 1.063     0.008       1.053
# 180               0.304    0.143       0.323 1.063     0.008       1.028
# 146               0.752    0.106       0.788 1.048     0.005       1.170
# 147               0.134    0.106       0.141 1.048     0.005       1.008
# 18                0.641    0.495       0.658 1.025     0.012       1.048
# 19                0.752    0.495       0.771 1.025     0.012       1.083
# 276               0.150    0.076       0.153 1.019     0.001       1.003
# 279               0.495    0.076       0.504 1.019     0.001       1.019

# %%
rules.sort_values('lift', ascending=False).head(20).head()
# Out:
#                                            antecedents  \
# 286  (Sides, Promos, Burgers & Sandwiches, Cold Bev...
# 315                                            (Menus)
# 310                                    (Promos, Menus)
# 291      (Sides, Burgers & Sandwiches, Cold Beverages)
# 190                                            (Menus)
#
#                                            consequents  antecedent support  \
# 286                                            (Menus)               0.240
# 315  (Sides, Promos, Burgers & Sandwiches, Cold Bev...               0.173
# 310      (Sides, Burgers & Sandwiches, Cold Beverages)               0.173
# 291                                    (Promos, Menus)               0.240
# 190      (Sides, Burgers & Sandwiches, Cold Beverages)               0.173
#
#      consequent support  support  confidence  lift  leverage  conviction
# 286               0.173    0.134       0.560 3.235     0.093       1.880
# 315               0.240    0.134       0.776 3.235     0.093       3.387
# 310               0.240    0.134       0.777 3.234     0.093       3.407
# 291               0.173    0.134       0.559 3.234     0.093       1.876
# 190               0.240    0.135       0.777 3.234     0.093       3.407

# %%
display(rules[phrase_filter(rules,'Cold Beverages')].head())
# Out:
#                antecedents             consequents  antecedent support  \
# 0                    (Box)        (Cold Beverages)               0.072
# 1         (Cold Beverages)                   (Box)               0.352
# 12  (Burgers & Sandwiches)        (Cold Beverages)               0.641
# 13        (Cold Beverages)  (Burgers & Sandwiches)               0.352
# 22               (Chicken)        (Cold Beverages)               0.443
#
#     consequent support  support  confidence  lift  leverage  conviction
# 0                0.352    0.072       0.989 2.811     0.046      56.728
# 1                0.072    0.072       0.203 2.811     0.046       1.164
# 12               0.352    0.258       0.403 1.146     0.033       1.086
# 13               0.641    0.258       0.735 1.146     0.033       1.352
# 22               0.352    0.175       0.395 1.124     0.019       1.072

# %%
display(rules[phrase_filter(rules,'Salads')].head())
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# #### Conclusions

# %% [markdown]
# - some obvious associacions can be found when not filtering data. It is not surprising that people who bought chicken, they migh also buy fries or cold beverage.
# - it is somehow interesting that people who bought:
#     - chicken are 2x likely to buy salad
#
#
# In the next step we would like to explore less popular groups of products like hot beverages, desserts, salads.

# %% [markdown]
# #### Keep carts with at least one item buought in category: hot beverages, desserts, salads, 'Breakfast', 'LSM'

# %%
product_groups = ['Hot Beverages', 'Desserts', 'Salads', 'Breakfast', 'LSM']
rules = analyze_basket(basket_sets[(basket_sets[product_groups] !=0).any(1)])
# Out:
#    support                itemsets
# 0    0.076                (Bucket)
# 1    0.473  (Burgers & Sandwiches)
# 2    0.296               (Chicken)
# 3    0.214        (Cold Beverages)
# 4    0.106            (Condiments)

# %%
rules.head()
# Out:
#   antecedents             consequents  antecedent support  consequent support  \
# 0   (Chicken)                (Bucket)               0.296               0.076
# 1    (Bucket)               (Chicken)               0.076               0.296
# 2    (Promos)                (Bucket)               0.998               0.076
# 3    (Bucket)                (Promos)               0.076               0.998
# 4   (Chicken)  (Burgers & Sandwiches)               0.296               0.473
#
#    support  confidence  lift  leverage  conviction
# 0    0.076       0.256 3.377     0.053       1.242
# 1    0.076       1.000 3.377     0.053   25320.651
# 2    0.076       0.076 1.000     0.000       1.000
# 3    0.076       0.998 1.000     0.000       1.188
# 4    0.144       0.485 1.027     0.004       1.024

# %%
for product in product_groups:
    display(product)
    display(rules[phrase_filter(rules,product)].sort_values('lift', ascending=False).head(50))
# Out:
# 'Hot Beverages'
#                                        antecedents  \
# 575                                (Sides, Promos)
# 578                       (Chicken, Hot Beverages)
# 210                                        (Sides)
# 209                       (Chicken, Hot Beverages)
# 579                                        (Sides)
# 574               (Chicken, Promos, Hot Beverages)
# 572                 (Sides, Promos, Hot Beverages)
# 581                                      (Chicken)
# 208                         (Sides, Hot Beverages)
# 211                                      (Chicken)
# 577                              (Chicken, Promos)
# 576                         (Sides, Hot Beverages)
# 497                         (Burgers & Sandwiches)
# 488                 (Sides, Promos, Hot Beverages)
# 493                 (Promos, Burgers & Sandwiches)
# 492                         (Sides, Hot Beverages)
# 143                         (Burgers & Sandwiches)
# 140                         (Sides, Hot Beverages)
# 491                                (Sides, Promos)
# 494          (Hot Beverages, Burgers & Sandwiches)
# 141          (Hot Beverages, Burgers & Sandwiches)
# 142                                        (Sides)
# 495                                        (Sides)
# 490  (Promos, Burgers & Sandwiches, Hot Beverages)
# 134                        (Promos, Hot Beverages)
# 139                         (Burgers & Sandwiches)
# 135                 (Promos, Burgers & Sandwiches)
# 138                                (Hot Beverages)
# 10                                 (Hot Beverages)
# 11                          (Burgers & Sandwiches)
# 206                       (Chicken, Hot Beverages)
# 207                                       (Promos)
# 573                (Sides, Hot Beverages, Chicken)
# 580                                       (Promos)
# 137                                       (Promos)
# 136          (Hot Beverages, Burgers & Sandwiches)
# 496                                       (Promos)
# 489   (Sides, Hot Beverages, Burgers & Sandwiches)
# 297                                       (Promos)
# 296                         (Sides, Hot Beverages)
#
#                                        consequents  antecedent support  \
# 575                       (Chicken, Hot Beverages)               0.493
# 578                                (Sides, Promos)               0.078
# 210                       (Chicken, Hot Beverages)               0.495
# 209                                        (Sides)               0.078
# 579               (Chicken, Promos, Hot Beverages)               0.495
# 574                                        (Sides)               0.078
# 572                                      (Chicken)               0.136
# 581                 (Sides, Promos, Hot Beverages)               0.296
# 208                                      (Chicken)               0.137
# 211                         (Sides, Hot Beverages)               0.296
# 577                         (Sides, Hot Beverages)               0.295
# 576                              (Chicken, Promos)               0.137
# 497                 (Sides, Promos, Hot Beverages)               0.473
# 488                         (Burgers & Sandwiches)               0.136
# 493                         (Sides, Hot Beverages)               0.472
# 492                 (Promos, Burgers & Sandwiches)               0.137
# 143                         (Sides, Hot Beverages)               0.473
# 140                         (Burgers & Sandwiches)               0.137
# 491          (Hot Beverages, Burgers & Sandwiches)               0.493
# 494                                (Sides, Promos)               0.141
# 141                                        (Sides)               0.141
# 142          (Hot Beverages, Burgers & Sandwiches)               0.495
# 495  (Promos, Burgers & Sandwiches, Hot Beverages)               0.495
# 490                                        (Sides)               0.141
# 134                         (Burgers & Sandwiches)               0.283
# 139                        (Promos, Hot Beverages)               0.473
# 135                                (Hot Beverages)               0.472
# 138                 (Promos, Burgers & Sandwiches)               0.284
# 10                          (Burgers & Sandwiches)               0.284
# 11                                 (Hot Beverages)               0.473
# 206                                       (Promos)               0.078
# 207                       (Chicken, Hot Beverages)               0.998
# 573                                       (Promos)               0.073
# 580                (Sides, Hot Beverages, Chicken)               0.998
# 137          (Hot Beverages, Burgers & Sandwiches)               0.998
# 136                                       (Promos)               0.141
# 496   (Sides, Hot Beverages, Burgers & Sandwiches)               0.998
# 489                                       (Promos)               0.093
# 297                         (Sides, Hot Beverages)               0.998
# 296                                       (Promos)               0.137
#
#      consequent support  support  confidence  lift  leverage  conviction
# 575               0.078    0.072       0.147 1.879     0.034       1.081
# 578               0.493    0.072       0.928 1.879     0.034       6.987
# 210               0.078    0.073       0.147 1.879     0.034       1.081
# 209               0.495    0.073       0.930 1.879     0.034       7.169
# 579               0.078    0.072       0.147 1.879     0.034       1.080
# 574               0.495    0.072       0.929 1.879     0.034       7.167
# 572               0.296    0.072       0.531 1.794     0.032       1.501
# 581               0.136    0.072       0.245 1.794     0.032       1.143
# 208               0.296    0.073       0.531 1.793     0.032       1.501
# 211               0.137    0.073       0.245 1.793     0.032       1.144
# 577               0.137    0.072       0.245 1.793     0.032       1.144
# 576               0.295    0.072       0.530 1.793     0.032       1.499
# 497               0.136    0.093       0.197 1.442     0.029       1.075
# 488               0.473    0.093       0.682 1.442     0.029       1.656
# 493               0.137    0.093       0.197 1.442     0.029       1.075
# 492               0.472    0.093       0.680 1.442     0.029       1.651
# 143               0.137    0.093       0.197 1.442     0.029       1.075
# 140               0.473    0.093       0.682 1.442     0.029       1.656
# 491               0.141    0.093       0.189 1.335     0.023       1.058
# 494               0.493    0.093       0.659 1.335     0.023       1.485
# 141               0.495    0.093       0.660 1.335     0.023       1.488
# 142               0.141    0.093       0.189 1.335     0.023       1.058
# 495               0.141    0.093       0.188 1.335     0.023       1.058
# 490               0.495    0.093       0.660 1.335     0.023       1.488
# 134               0.473    0.141       0.498 1.053     0.007       1.050
# 139               0.283    0.141       0.298 1.053     0.007       1.022
# 135               0.284    0.141       0.299 1.053     0.007       1.022
# 138               0.472    0.141       0.497 1.053     0.007       1.050
# 10                0.473    0.141       0.498 1.053     0.007       1.050
# 11                0.284    0.141       0.299 1.053     0.007       1.022
# 206               0.998    0.078       0.998 1.000     0.000       1.086
# 207               0.078    0.078       0.078 1.000     0.000       1.000
# 573               0.998    0.072       0.998 1.000     0.000       1.078
# 580               0.073    0.072       0.073 1.000     0.000       1.000
# 137               0.141    0.141       0.141 1.000     0.000       1.000
# 136               0.998    0.141       0.998 1.000     0.000       1.062
# 496               0.093    0.093       0.093 1.000     0.000       1.000
# 489               0.998    0.093       0.998 1.000     0.000       1.034
# 297               0.137    0.136       0.137 1.000     0.000       1.000
# 296               0.998    0.136       0.998 1.000     0.000       1.008
# 'Desserts'
#                                          antecedents  \
# 787                                          (Value)
# 760  (Sides, Promos, Burgers & Sandwiches, Desserts)
# 475          (Sides, Burgers & Sandwiches, Desserts)
# 486                                          (Value)
# 764          (Sides, Burgers & Sandwiches, Desserts)
# 783                                  (Promos, Value)
# 481                    (Burgers & Sandwiches, Value)
# 480                                (Sides, Desserts)
# 765                        (Sides, Promos, Desserts)
# 782                    (Burgers & Sandwiches, Value)
# 773            (Promos, Burgers & Sandwiches, Value)
# 774                                (Sides, Desserts)
# 288                                          (Value)
# 285                                (Sides, Desserts)
# 640                                          (Value)
# 631                        (Sides, Promos, Desserts)
# 635                                (Sides, Desserts)
# 636                                  (Promos, Value)
# 775                    (Sides, Burgers & Sandwiches)
# 772                        (Promos, Value, Desserts)
# 478                    (Sides, Burgers & Sandwiches)
# 483                                (Value, Desserts)
# 767            (Sides, Promos, Burgers & Sandwiches)
# 780                                (Value, Desserts)
# 711            (Sides, Promos, Burgers & Sandwiches)
# 722                       (Desserts, Cold Beverages)
# 715               (Promos, Desserts, Cold Beverages)
# 718                    (Sides, Burgers & Sandwiches)
# 392                       (Cold Beverages, Desserts)
# 387                    (Sides, Burgers & Sandwiches)
# 477          (Burgers & Sandwiches, Value, Desserts)
# 484                                          (Sides)
# 763  (Promos, Burgers & Sandwiches, Value, Desserts)
# 784                                          (Sides)
# 771          (Burgers & Sandwiches, Value, Desserts)
# 776                                  (Sides, Promos)
# 201                              (Chicken, Desserts)
# 204                                          (Value)
# 561                      (Chicken, Promos, Desserts)
# 570                                          (Value)
# 566                                  (Promos, Value)
# 565                              (Chicken, Desserts)
# 777                                   (Sides, Value)
# 770         (Promos, Burgers & Sandwiches, Desserts)
# 482                 (Burgers & Sandwiches, Desserts)
# 479                                   (Sides, Value)
# 769                           (Sides, Promos, Value)
# 778                 (Burgers & Sandwiches, Desserts)
# 352        (Chicken, Burgers & Sandwiches, Desserts)
# 357                                          (Sides)
#
#                                          consequents  antecedent support  \
# 787  (Sides, Promos, Burgers & Sandwiches, Desserts)               0.226
# 760                                          (Value)               0.219
# 475                                          (Value)               0.220
# 486          (Sides, Burgers & Sandwiches, Desserts)               0.226
# 764                                  (Promos, Value)               0.220
# 783          (Sides, Burgers & Sandwiches, Desserts)               0.226
# 481                                (Sides, Desserts)               0.172
# 480                    (Burgers & Sandwiches, Value)               0.299
# 765                    (Burgers & Sandwiches, Value)               0.298
# 782                        (Sides, Promos, Desserts)               0.172
# 773                                (Sides, Desserts)               0.172
# 774            (Promos, Burgers & Sandwiches, Value)               0.299
# 288                                (Sides, Desserts)               0.226
# 285                                          (Value)               0.299
# 640                        (Sides, Promos, Desserts)               0.226
# 631                                          (Value)               0.298
# 635                                  (Promos, Value)               0.299
# 636                                (Sides, Desserts)               0.226
# 775                        (Promos, Value, Desserts)               0.337
# 772                    (Sides, Burgers & Sandwiches)               0.164
# 478                                (Value, Desserts)               0.337
# 483                    (Sides, Burgers & Sandwiches)               0.165
# 767                                (Value, Desserts)               0.336
# 780            (Sides, Promos, Burgers & Sandwiches)               0.165
# 711                       (Desserts, Cold Beverages)               0.336
# 722            (Sides, Promos, Burgers & Sandwiches)               0.107
# 715                    (Sides, Burgers & Sandwiches)               0.106
# 718               (Promos, Desserts, Cold Beverages)               0.337
# 392                    (Sides, Burgers & Sandwiches)               0.107
# 387                       (Cold Beverages, Desserts)               0.337
# 477                                          (Sides)               0.127
# 484          (Burgers & Sandwiches, Value, Desserts)               0.495
# 763                                          (Sides)               0.127
# 784  (Promos, Burgers & Sandwiches, Value, Desserts)               0.495
# 771                                  (Sides, Promos)               0.127
# 776          (Burgers & Sandwiches, Value, Desserts)               0.493
# 201                                          (Value)               0.159
# 204                              (Chicken, Desserts)               0.226
# 561                                          (Value)               0.159
# 570                      (Chicken, Promos, Desserts)               0.226
# 566                              (Chicken, Desserts)               0.226
# 565                                  (Promos, Value)               0.159
# 777         (Promos, Burgers & Sandwiches, Desserts)               0.214
# 770                                   (Sides, Value)               0.300
# 482                                   (Sides, Value)               0.300
# 479                 (Burgers & Sandwiches, Desserts)               0.214
# 769                 (Burgers & Sandwiches, Desserts)               0.213
# 778                           (Sides, Promos, Value)               0.300
# 352                                          (Sides)               0.085
# 357        (Chicken, Burgers & Sandwiches, Desserts)               0.495
#
#      consequent support  support  confidence  lift  leverage  conviction
# 787               0.219    0.125       0.552 2.520     0.075       1.744
# 760               0.226    0.125       0.570 2.520     0.075       1.800
# 475               0.226    0.125       0.570 2.520     0.076       1.800
# 486               0.220    0.125       0.554 2.520     0.076       1.748
# 764               0.226    0.125       0.569 2.520     0.075       1.795
# 783               0.220    0.125       0.554 2.520     0.075       1.748
# 481               0.299    0.125       0.726 2.430     0.074       2.561
# 480               0.172    0.125       0.419 2.430     0.074       1.425
# 765               0.172    0.125       0.419 2.430     0.074       1.425
# 782               0.298    0.125       0.724 2.430     0.074       2.548
# 773               0.299    0.125       0.726 2.430     0.074       2.560
# 774               0.172    0.125       0.418 2.430     0.074       1.423
# 288               0.299    0.154       0.681 2.280     0.087       2.201
# 285               0.226    0.154       0.516 2.280     0.087       1.598
# 640               0.298    0.154       0.680 2.280     0.086       2.192
# 631               0.226    0.154       0.516 2.280     0.086       1.598
# 635               0.226    0.154       0.515 2.280     0.086       1.595
# 636               0.299    0.154       0.681 2.280     0.086       2.201
# 775               0.164    0.125       0.371 2.261     0.070       1.329
# 772               0.337    0.125       0.761 2.261     0.070       2.777
# 478               0.165    0.125       0.372 2.261     0.070       1.330
# 483               0.337    0.125       0.761 2.261     0.070       2.776
# 767               0.165    0.125       0.372 2.260     0.070       1.330
# 780               0.336    0.125       0.759 2.260     0.070       2.758
# 711               0.107    0.075       0.224 2.103     0.039       1.151
# 722               0.336    0.075       0.706 2.103     0.039       2.262
# 715               0.337    0.075       0.708 2.103     0.039       2.272
# 718               0.106    0.075       0.224 2.103     0.039       1.151
# 392               0.337    0.075       0.708 2.103     0.040       2.272
# 387               0.107    0.075       0.224 2.103     0.040       1.151
# 477               0.495    0.125       0.987 1.996     0.063      40.230
# 484               0.127    0.125       0.253 1.996     0.063       1.169
# 763               0.495    0.125       0.987 1.996     0.062      40.135
# 784               0.127    0.125       0.253 1.996     0.062       1.169
# 771               0.493    0.125       0.985 1.996     0.062      33.914
# 776               0.127    0.125       0.253 1.996     0.062       1.169
# 201               0.226    0.071       0.448 1.981     0.035       1.402
# 204               0.159    0.071       0.316 1.981     0.035       1.228
# 561               0.226    0.071       0.448 1.980     0.035       1.402
# 570               0.159    0.071       0.315 1.980     0.035       1.227
# 566               0.159    0.071       0.316 1.980     0.035       1.228
# 565               0.226    0.071       0.447 1.980     0.035       1.400
# 777               0.300    0.125       0.584 1.949     0.061       1.683
# 770               0.214    0.125       0.417 1.949     0.061       1.348
# 482               0.214    0.125       0.417 1.948     0.061       1.348
# 479               0.300    0.125       0.585 1.948     0.061       1.687
# 769               0.300    0.125       0.585 1.948     0.061       1.687
# 778               0.213    0.125       0.416 1.948     0.061       1.347
# 352               0.495    0.081       0.956 1.933     0.039      11.555
# 357               0.085    0.081       0.164 1.933     0.039       1.095
# 'Salads'
#            antecedents        consequents  antecedent support  \
# 215          (Chicken)   (Promos, Salads)               0.296
# 214   (Promos, Salads)          (Chicken)               0.136
# 212  (Chicken, Promos)           (Salads)               0.295
# 217           (Salads)  (Chicken, Promos)               0.136
# 27            (Salads)          (Chicken)               0.136
# 26           (Chicken)           (Salads)               0.296
# 309           (Salads)    (Sides, Promos)               0.136
# 304    (Sides, Promos)           (Salads)               0.493
# 306   (Promos, Salads)            (Sides)               0.136
# 307            (Sides)   (Promos, Salads)               0.495
# 57            (Salads)            (Sides)               0.136
# 56             (Sides)           (Salads)               0.495
# 213  (Chicken, Salads)           (Promos)               0.079
# 216           (Promos)  (Chicken, Salads)               0.998
# 305    (Sides, Salads)           (Promos)               0.091
# 308           (Promos)    (Sides, Salads)               0.998
# 53            (Salads)           (Promos)               0.136
# 52            (Promos)           (Salads)               0.998
#
#      consequent support  support  confidence  lift  leverage  conviction
# 215               0.136    0.079       0.266 1.956     0.039       1.177
# 214               0.296    0.079       0.579 1.956     0.039       1.673
# 212               0.136    0.079       0.267 1.956     0.039       1.178
# 217               0.295    0.079       0.578 1.956     0.039       1.670
# 27                0.296    0.079       0.579 1.956     0.039       1.672
# 26                0.136    0.079       0.267 1.956     0.039       1.178
# 309               0.493    0.091       0.669 1.356     0.024       1.531
# 304               0.136    0.091       0.185 1.356     0.024       1.060
# 306               0.495    0.091       0.671 1.356     0.024       1.534
# 307               0.136    0.091       0.184 1.356     0.024       1.059
# 57                0.495    0.091       0.671 1.356     0.024       1.534
# 56                0.136    0.091       0.185 1.356     0.024       1.059
# 213               0.998    0.079       0.998 1.000     0.000       1.256
# 216               0.079    0.079       0.079 1.000     0.000       1.000
# 305               0.998    0.091       0.998 1.000     0.000       1.079
# 308               0.091    0.091       0.091 1.000     0.000       1.000
# 53                0.998    0.136       0.998 1.000     0.000       1.077
# 52                0.136    0.136       0.136 1.000     0.000       1.000
# 'Breakfast'
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
# 'LSM'
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# #### Conclusions

# %% [markdown]
# - **Some products groups are special**
#     - Desserts, hot beverages or salads are rarely sold by themselves. Customers who already bought other items adds those to the cart.
#     - Desserts are usually bought when customer is having a coupon or if there is a promotion for it.
# - **Juice with chicken nuggets**.
#     - Orange juice is common next choice when someone buys chicken bites (nuggets).
# - It might make sense to recommend dessert purchase, only when user already selected several other items or a hot beverage. We could recommend orange juice when it is likely that customers are parents. It seems that some product groups are an “extra” thing to buy, but never the main reason to enter restaurant, so there is little point in exposing them heavily at the early stage.
